# %% [markdown]
# # **<span style="color:#6daa9f;">IMPORTING IMPORTANT LIBRARIES</span>**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %% [markdown]
# # **<span style="color:#6daa9f;">LOADING DATA</span>**

# %%
#loading data
data = pd.read_csv("../input/heart-failure-clinical-data/heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# **About the data:**
#
# * age: Age of the patient
# * anaemia: If the patient had the haemoglobin below the normal range
# * creatinine_phosphokinase: The level of the creatine phosphokinase in the blood in mcg/L
# * diabetes: If the patient was diabetic
# * ejection_fraction: Ejection fraction is a measurement of how much blood the left ventricle pumps out with each contraction
# * high_blood_pressure: If the patient had hypertension
# * platelets: Platelet count of blood in kiloplatelets/mL
# * serum_creatinine: The level of serum creatinine in the blood in mg/dL
# * serum_sodium: The level of serum sodium in the blood in mEq/L
# * sex: The sex of the patient
# * smoking: If the patient smokes actively or ever did in past
# * time: It is the time of the patient's follow-up visit for the disease in months
# * DEATH_EVENT: If the patient deceased during the follow-up period

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA ANALYSIS</span>**

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
cols= ["#6daa9f","#774571"]
sns.countplot(x= data["DEATH_EVENT"], palette= cols)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='count'>

# %% [markdown]
# Point to note is that there is an imbalance in the data.

# %%
#Examaning a corelation matrix of all the features 
cmap = sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

# %% [markdown]
# **Notable points:**
# * Time of the patient's follow-up visit for the disease is crucial in as initial diagnosis with cardiovascular issue and treatment reduces the chances of any fatality. It holds and inverse relation.
# * Ejection fraction is the second most important feature. It is quite expected as it is basically the efficiency of the heart.
# * Age of the patient is the third most correlated feature. Clearly as heart's functioning declines with ageing

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
#colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
Days_of_week=sns.countplot(x=data['age'],data=data, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
# Boxen and swarm plot of some non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
    sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# I spotted outliers on our dataset. I didn't remove them yet as it may lead to overfitting. Though we may end up with better statistics. In this case, with medical data, the outliers may be an important deciding factor.
#
# Next, we examine the kdeplot of time and age as they both are significant features.

# %%
sns.kdeplot(x=data["time"], y=data["age"], hue =data["DEATH_EVENT"], palette=cols)
# Out:
# <AxesSubplot:xlabel='time', ylabel='age'>

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA PREPROCESSING</span>**

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.265205e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  3.594301e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  3.713120e-18  1.001676 -0.576918 -0.480393
# diabetes                  299.0  1.113936e-16  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0  3.341808e-18  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0 -4.841909e-16  1.001676 -0.735688 -0.735688
# platelets                 299.0  1.009969e-16  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0 -2.227872e-18  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.627435e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -5.940993e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -3.861645e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.069379e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#looking at the scaled features
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df)
plt.xticks(rotation=90)
plt.show()

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=7)

# %% [markdown]
# # **<span style="color:#6daa9f;">MODEL BUILDING</span>**

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from keras.optimizers import SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 123ms/step - loss: 0.6929 - accuracy: 0.5635 - val_loss: 0.6921 - val_accuracy: 0.6667
# Epoch 2/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6920 - accuracy: 0.6627 - val_loss: 0.6911 - val_accuracy: 0.6667
# Epoch 3/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6909 - accuracy: 0.6721 - val_loss: 0.6901 - val_accuracy: 0.6667
# Epoch 4/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6903 - accuracy: 0.6504 - val_loss: 0.6892 - val_accuracy: 0.6667
# Epoch 5/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6894 - accuracy: 0.6482 - val_loss: 0.6881 - val_accuracy: 0.6667
# Epoch 6/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6884 - accuracy: 0.6454 - val_loss: 0.6871 - val_accuracy: 0.6667
# Epoch 7/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6875 - accuracy: 0.6471 - val_loss: 0.6860 - val_accuracy: 0.6667
# Epoch 8/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6861 - accuracy: 0.6584 - val_loss: 0.6848 - val_accuracy: 0.6667
# Epoch 9/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6841 - accuracy: 0.6796 - val_loss: 0.6836 - val_accuracy: 0.6667
# Epoch 10/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6828 - accuracy: 0.6787 - val_loss: 0.6823 - val_accuracy: 0.6667
# Epoch 11/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6816 - accuracy: 0.6666 - val_loss: 0.6809 - val_accuracy: 0.6667
# Epoch 12/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6817 - accuracy: 0.6465 - val_loss: 0.6793 - val_accuracy: 0.6667
# Epoch 13/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6793 - accuracy: 0.6571 - val_loss: 0.6774 - val_accuracy: 0.6667
# Epoch 14/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6789 - accuracy: 0.6421 - val_loss: 0.6753 - val_accuracy: 0.6667
# Epoch 15/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6766 - accuracy: 0.6514 - val_loss: 0.6729 - val_accuracy: 0.6667
# Epoch 16/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6760 - accuracy: 0.6495 - val_loss: 0.6701 - val_accuracy: 0.6667
# Epoch 17/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6763 - accuracy: 0.6194 - val_loss: 0.6668 - val_accuracy: 0.6667
# Epoch 18/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6693 - accuracy: 0.6296 - val_loss: 0.6628 - val_accuracy: 0.6667
# Epoch 19/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6637 - accuracy: 0.6517 - val_loss: 0.6581 - val_accuracy: 0.6667
# Epoch 20/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6568 - accuracy: 0.6773 - val_loss: 0.6527 - val_accuracy: 0.6667
# Epoch 21/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6486 - accuracy: 0.6546 - val_loss: 0.6465 - val_accuracy: 0.6667
# Epoch 22/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6464 - accuracy: 0.6387 - val_loss: 0.6390 - val_accuracy: 0.6667
# Epoch 23/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6473 - accuracy: 0.6385 - val_loss: 0.6306 - val_accuracy: 0.6667
# Epoch 24/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6423 - accuracy: 0.6450 - val_loss: 0.6222 - val_accuracy: 0.6667
# Epoch 25/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6122 - accuracy: 0.6934 - val_loss: 0.6118 - val_accuracy: 0.6667
# Epoch 26/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6011 - accuracy: 0.6632 - val_loss: 0.6000 - val_accuracy: 0.6667
# Epoch 27/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5926 - accuracy: 0.6825 - val_loss: 0.5874 - val_accuracy: 0.6667
# Epoch 28/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6015 - accuracy: 0.7339 - val_loss: 0.5755 - val_accuracy: 0.6889
# Epoch 29/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5690 - accuracy: 0.7555 - val_loss: 0.5634 - val_accuracy: 0.7111
# Epoch 30/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5499 - accuracy: 0.7563 - val_loss: 0.5513 - val_accuracy: 0.7111
# Epoch 31/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5609 - accuracy: 0.7699 - val_loss: 0.5405 - val_accuracy: 0.7333
# Epoch 32/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5683 - accuracy: 0.7560 - val_loss: 0.5306 - val_accuracy: 0.6889
# Epoch 33/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5353 - accuracy: 0.7566 - val_loss: 0.5219 - val_accuracy: 0.7556
# Epoch 34/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5157 - accuracy: 0.7560 - val_loss: 0.5122 - val_accuracy: 0.7778
# Epoch 35/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5183 - accuracy: 0.7020 - val_loss: 0.5026 - val_accuracy: 0.7778
# Epoch 36/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5108 - accuracy: 0.7073 - val_loss: 0.4948 - val_accuracy: 0.8000
# Epoch 37/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5411 - accuracy: 0.7621 - val_loss: 0.4879 - val_accuracy: 0.8000
# Epoch 38/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4939 - accuracy: 0.7644 - val_loss: 0.4812 - val_accuracy: 0.8222
# Epoch 39/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4855 - accuracy: 0.8162 - val_loss: 0.4763 - val_accuracy: 0.8222
# Epoch 40/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4915 - accuracy: 0.7412 - val_loss: 0.4728 - val_accuracy: 0.8444
# Epoch 41/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5183 - accuracy: 0.7795 - val_loss: 0.4699 - val_accuracy: 0.8444
# Epoch 42/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4728 - accuracy: 0.8119 - val_loss: 0.4659 - val_accuracy: 0.8444
# Epoch 43/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4584 - accuracy: 0.8474 - val_loss: 0.4619 - val_accuracy: 0.8444
# Epoch 44/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4980 - accuracy: 0.7789 - val_loss: 0.4597 - val_accuracy: 0.8444
# Epoch 45/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4752 - accuracy: 0.8552 - val_loss: 0.4586 - val_accuracy: 0.8444
# Epoch 46/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4745 - accuracy: 0.7535 - val_loss: 0.4573 - val_accuracy: 0.8222
# Epoch 47/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4643 - accuracy: 0.8263 - val_loss: 0.4570 - val_accuracy: 0.8222
# Epoch 48/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4983 - accuracy: 0.7820 - val_loss: 0.4575 - val_accuracy: 0.8222
# Epoch 49/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5116 - accuracy: 0.7937 - val_loss: 0.4575 - val_accuracy: 0.8222
# Epoch 50/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4952 - accuracy: 0.8294 - val_loss: 0.4563 - val_accuracy: 0.8222
# Epoch 51/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4421 - accuracy: 0.8052 - val_loss: 0.4540 - val_accuracy: 0.8222
# Epoch 52/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5172 - accuracy: 0.8088 - val_loss: 0.4519 - val_accuracy: 0.8222
# Epoch 53/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4307 - accuracy: 0.8240 - val_loss: 0.4499 - val_accuracy: 0.8222
# Epoch 54/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4761 - accuracy: 0.7486 - val_loss: 0.4488 - val_accuracy: 0.8222
# Epoch 55/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4106 - accuracy: 0.8574 - val_loss: 0.4483 - val_accuracy: 0.8222
# Epoch 56/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4925 - accuracy: 0.7753 - val_loss: 0.4476 - val_accuracy: 0.8444
# Epoch 57/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5007 - accuracy: 0.8157 - val_loss: 0.4472 - val_accuracy: 0.8222
# Epoch 58/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4708 - accuracy: 0.8159 - val_loss: 0.4470 - val_accuracy: 0.8222
# Epoch 59/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4449 - accuracy: 0.8132 - val_loss: 0.4458 - val_accuracy: 0.8222
# Epoch 60/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4495 - accuracy: 0.8082 - val_loss: 0.4444 - val_accuracy: 0.8222
# Epoch 61/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4691 - accuracy: 0.7788 - val_loss: 0.4437 - val_accuracy: 0.8222
# Epoch 62/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4188 - accuracy: 0.8245 - val_loss: 0.4447 - val_accuracy: 0.8222
# Epoch 63/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5122 - accuracy: 0.7824 - val_loss: 0.4456 - val_accuracy: 0.8222
# Epoch 64/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3961 - accuracy: 0.8287 - val_loss: 0.4458 - val_accuracy: 0.8222
# Epoch 65/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4426 - accuracy: 0.7967 - val_loss: 0.4460 - val_accuracy: 0.8444
# Epoch 66/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4271 - accuracy: 0.8472 - val_loss: 0.4462 - val_accuracy: 0.8444
# Epoch 67/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4472 - accuracy: 0.7897 - val_loss: 0.4441 - val_accuracy: 0.8444
# Epoch 68/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4156 - accuracy: 0.8155 - val_loss: 0.4428 - val_accuracy: 0.8444
# Epoch 69/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4716 - accuracy: 0.7991 - val_loss: 0.4424 - val_accuracy: 0.8444
# Epoch 70/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3686 - accuracy: 0.8381 - val_loss: 0.4435 - val_accuracy: 0.8444
# Epoch 71/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3858 - accuracy: 0.8441 - val_loss: 0.4460 - val_accuracy: 0.8444
# Epoch 72/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4239 - accuracy: 0.8075 - val_loss: 0.4484 - val_accuracy: 0.8444
# Epoch 73/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4706 - accuracy: 0.8124 - val_loss: 0.4501 - val_accuracy: 0.8444
# Epoch 74/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4408 - accuracy: 0.8011 - val_loss: 0.4509 - val_accuracy: 0.8444
# Epoch 75/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4757 - accuracy: 0.7906 - val_loss: 0.4499 - val_accuracy: 0.8444
# Epoch 76/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4239 - accuracy: 0.8095 - val_loss: 0.4487 - val_accuracy: 0.8444
# Epoch 77/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4311 - accuracy: 0.8375 - val_loss: 0.4469 - val_accuracy: 0.8444
# Epoch 78/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4454 - accuracy: 0.8210 - val_loss: 0.4456 - val_accuracy: 0.8222
# Epoch 79/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4379 - accuracy: 0.8363 - val_loss: 0.4442 - val_accuracy: 0.8222
# Epoch 80/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3938 - accuracy: 0.8632 - val_loss: 0.4433 - val_accuracy: 0.8222
# Epoch 81/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3974 - accuracy: 0.7887 - val_loss: 0.4442 - val_accuracy: 0.8222
# Epoch 82/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4847 - accuracy: 0.8100 - val_loss: 0.4438 - val_accuracy: 0.8222
# Epoch 83/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3952 - accuracy: 0.8182 - val_loss: 0.4431 - val_accuracy: 0.8222
# Epoch 84/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4006 - accuracy: 0.8506 - val_loss: 0.4420 - val_accuracy: 0.8222
# Epoch 85/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4242 - accuracy: 0.7983 - val_loss: 0.4428 - val_accuracy: 0.8222
# Epoch 86/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4322 - accuracy: 0.8531 - val_loss: 0.4438 - val_accuracy: 0.8222
# Epoch 87/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3837 - accuracy: 0.8632 - val_loss: 0.4438 - val_accuracy: 0.8222
# Epoch 88/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4323 - accuracy: 0.8097 - val_loss: 0.4442 - val_accuracy: 0.8222

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 77.07%

# %% [markdown]
# **Plotting training and validation loss over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# **Plotting training and validation accuracy over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **<span style="color:#6daa9f;">CONCLUSIONS</span>**

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        57
#            1       0.61      0.61      0.61        18
#
#     accuracy                           0.81        75
#    macro avg       0.74      0.74      0.74        75
# weighted avg       0.81      0.81      0.81        75
